# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from ann_visualizer.visualize import ann_viz
from keras.utils import plot_model

# Load your dataset
data = pd.read_csv('E:\Hamza Important\Languages Practice\Python\ML Honours\ML Honours\students.csv')

model = Sequential()
model.add(Dense(12, input_dim=X.shape[1], activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X, y, epochs=150, batch_size=10, verbose=0)

ann_viz(model, title="Neural Network Model Visualization")

plot_model(model, to_file='model_structure.png', show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Hamza Important\Languages Practice\Python\ML Honours\ML Honours\1.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell:/e%3A/Hamza%20Important/Languages%20Practice/Python/ML%20Honours/ML%20Honours/1.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> data = pd.read_csv('E:\Hamza Important\Languages Practice\Python\ML Honours\ML Honours\students.csv')
#      <a href='vscode-notebook-cell:/e%3A/Hamza%20Important/Languages%20Practice/Python/ML%20Honours/ML%20Honours/1.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> model = Sequential()
# ---> <a href='vscode-notebook-cell:/e%3A/Hamza%20Important/Languages%20Practice/Python/ML%20Honours/ML%20Honours/1.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> model.add(Dense(12, input_dim=X.shape[1], activation='relu'))
# ...
